# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# %%
# MI_idx = pd.read_csv("/Users/merieldoyle/Desktop/ckMI/data/MI_idx.csv", index_col = None)
# MI_idx = pd.DataFrame(MI_idx)

# %%
# # drop common
# MI_idx = MI_idx.drop(["common"], axis = 1)

# %%
# # define liberal by politics <= 4, conservative by politics > 4

# MI_idx["politics 2"] = np.where(MI_idx["politics"] > 4, True, False)
# MI_idx["politics 2"] = MI_idx["politics 2"].map({True: "conservative", False: "liberal"})
# MI_idx = MI_idx.drop(["politics"], axis = 1)

# %%
# # move politics to index 1

# columns = MI_idx.columns.tolist()
# politics = columns.pop(9)
# columns.insert(1, politics)
# MI_idx = MI_idx[columns]

# %%
# wide_df_2 = pd.pivot_table(MI_idx, 
#                          index = 'condition', 
#                          columns = 'politics 2', 
#                          values = MI_idx.columns[:9], 
#                          aggfunc = 'mean')
# # wide_df_2.columns = wide_df_2.columns.map('{0[0]}_{0[1]}'.format) # combine column labels to avoid multi-level indexing
# wide_df_2
# wide_df_2.to_csv("wide_df.csv")

# %%
MI_idx = pd.read_csv("/Users/merieldoyle/Desktop/ckMI/data/wide_df_transformed.csv", index_col = None)
MI_idx
# Out:
#          condition   question      politics      mean
# 0       depression    control  conservative  3.260000
# 1            drugs    control  conservative  3.781690
# 2           fetish    control  conservative  3.914286
# 3              gay    control  conservative  3.083333
# 4            obese    control  conservative  5.225131
# ..             ...        ...           ...       ...
# 155      pedophile  wrongness       liberal  6.561765
# 156     psychopath  wrongness       liberal  5.568807
# 157         racist  wrongness       liberal  6.501484
# 158  schizophrenia  wrongness       liberal  3.154079
# 159    transgender  wrongness       liberal  2.271233
#
# [160 rows x 4 columns]

# %%
# define cols using RGBA color codes

cols = {('mental illness', 'liberal'): (0.0, 0.447, 0.741, 1.0),
        ('mental illness', 'conservative'): (0.0, 0.447, 0.741, 1.0),
        ('genes', 'liberal'): (0.85, 0.325, 0.098, 1.0),
        ('genes', 'conservative'): (0.85, 0.325, 0.098, 1.0),
        ('wrongness', 'liberal'): (0.95, 0.6, 0.6, 1.0),
        ('wrongness', 'conservative'): (0.95, 0.6, 0.6, 1.0),
        ('punishment', 'liberal'): (0.5, 0.0, 0.5, 1.0),
        ('punishment', 'conservative'): (0.5, 0.0, 0.5, 1.0),
        ('desired change', 'liberal'): (0.0, 0.5, 0.0, 1.0),
        ('desired change', 'conservative'): (0.0, 0.5, 0.0, 1.0),
        ('control', 'liberal'): (0.65, 0.35, 0.0, 1.0),
        ('control', 'conservative'): (0.65, 0.35, 0.0, 1.0),
        ('difficulty changing', 'liberal'): (1.0, 0.498, 0.0, 1.0),
        ('difficulty changing', 'conservative'): (1.0, 0.498, 0.0, 1.0),
        ('internal distress', 'liberal'): (0.25, 0.88, 0.82, 1.0),
        ('internal distress', 'conservative'): (0.25, 0.88, 0.82, 1.0)}

cols
# Out:
# {('mental illness', 'liberal'): (0.0, 0.447, 0.741, 1.0),
#  ('mental illness', 'conservative'): (0.0, 0.447, 0.741, 1.0),
#  ('genes', 'liberal'): (0.85, 0.325, 0.098, 1.0),
#  ('genes', 'conservative'): (0.85, 0.325, 0.098, 1.0),
#  ('wrongness', 'liberal'): (0.95, 0.6, 0.6, 1.0),
#  ('wrongness', 'conservative'): (0.95, 0.6, 0.6, 1.0),
#  ('punishment', 'liberal'): (0.5, 0.0, 0.5, 1.0),
#  ('punishment', 'conservative'): (0.5, 0.0, 0.5, 1.0),
#  ('desired change', 'liberal'): (0.0, 0.5, 0.0, 1.0),
#  ('desired change', 'conservative'): (0.0, 0.5, 0.0, 1.0),
#  ('control', 'liberal'): (0.65, 0.35, 0.0, 1.0),
#  ('control', 'conservative'): (0.65, 0.35, 0.0, 1.0),
#  ('difficulty changing', 'liberal'): (1.0, 0.498, 0.0, 1.0),
#  ('difficulty changing', 'conservative'): (1.0, 0.498, 0.0, 1.0),
#  ('internal distress', 'liberal'): (0.25, 0.88, 0.82, 1.0),
#  ('internal distress', 'conservative'): (0.25, 0.88, 0.82, 1.0)}

# %%
def get_color(q, hue):
    key = (q, hue)
    if key in cols:
        # print(f"Key {key} found in cols dictionary!")
        return tuple(cols[key][:4])  # return the RGB values as a tuple
    else:
        # print(f"Key {key} not found in cols dictionary!")
        return (0.5, 0.5, 0.5, 0.5)  # or some other default color
    
# [get_color(q, p) for q, p in zip(MI_idx.question, MI_idx.politics)]

# %%
palette_dict = {q: {hue: get_color(q, hue) for hue in MI_idx.politics.unique()} for q in MI_idx.question.unique()}
        
for q, pol in zip(MI_idx.question, MI_idx.politics):
    color = palette_dict[q][pol]

# color

# %%
flattened_palette = {}
for condition, palette_dict in palette_dict.items():
    for politics, color in palette_dict.items():
        key = f"{politics}_{condition}"
        flattened_palette[key] = color

flattened_palette
# Out:
# {'conservative_control': (0.65, 0.35, 0.0, 1.0),
#  'liberal_control': (0.65, 0.35, 0.0, 1.0),
#  'conservative_desired change': (0.0, 0.5, 0.0, 1.0),
#  'liberal_desired change': (0.0, 0.5, 0.0, 1.0),
#  'conservative_difficulty changing': (1.0, 0.498, 0.0, 1.0),
#  'liberal_difficulty changing': (1.0, 0.498, 0.0, 1.0),
#  'conservative_genes': (0.85, 0.325, 0.098, 1.0),
#  'liberal_genes': (0.85, 0.325, 0.098, 1.0),
#  'conservative_internal distress': (0.25, 0.88, 0.82, 1.0),
#  'liberal_internal distress': (0.25, 0.88, 0.82, 1.0),
#  'conservative_mental illness': (0.0, 0.447, 0.741, 1.0),
#  'liberal_mental illness': (0.0, 0.447, 0.741, 1.0),
#  'conservative_punishment': (0.5, 0.0, 0.5, 1.0),
#  'liberal_punishment': (0.5, 0.0, 0.5, 1.0),
#  'conservative_wrongness': (0.95, 0.6, 0.6, 1.0),
#  'liberal_wrongness': (0.95, 0.6, 0.6, 1.0)}

# %%
# create a new column 'hue' by combining the 'politics' and 'condition' columns with an underscore
MI_idx['hue'] = MI_idx['politics'] + '_' + MI_idx['question']

# MI_idx

# %%
# cat = sns.catplot(data = MI_idx, 
#                   col = "condition",
#                   col_wrap = 5,
#                   x = "question",
#                   y = "mean",
#                   kind = "bar",
#                   hue = "hue",
#                   palette = flattened_palette)

# for axes in cat.axes.flat:
#     _ = axes.set_xticklabels(axes.get_xticklabels(), rotation = 40, ha = 'right')
    
# plt.show()

# %%
# def custom_barplot(x, y, hue, data, width, palette, **kwargs):
#     x_categories = data[x].unique()
#     hue_categories = data[hue].unique()
    
#     for i, x_val in enumerate(x_categories):
#         x_data = data[data[x] == x_val]
#         for j, hue_val in enumerate(hue_categories):
#             hue_data = x_data[x_data[hue] == hue_val]
#             kwargs_no_color = {k: v for k, v in kwargs.items() if k != "color"}
#             plt.bar(i - width / 2 + j * width / len(hue_categories),
#                     hue_data[y].mean(),
#                     width=width / len(hue_categories),
#                     color=palette[hue_val],
#                     **kwargs_no_color)

# # Create FacetGrid with the custom barplot function
# g = sns.FacetGrid(data=MI_idx, col="condition", col_wrap=5, sharex=False, sharey=True, height=3, aspect=1)
# g.map_dataframe(custom_barplot, x="question", y="mean", hue="hue", width=0.5, palette=flattened_palette)

# # Add a legend
# g.add_legend(title="Hue", labels=list(flattened_palette.keys()), label_order=list(flattened_palette.keys()), bbox_to_anchor=(1, 1))

# plt.show()

# %%
# def custom_barplot(x, y, hue, data, width, palette, **kwargs):
#     x_categories = data[x].unique()
#     hue_categories = data[hue].unique()
    
#     for i, x_val in enumerate(x_categories):
#         x_data = data[data[x] == x_val]
#         for j, hue_val in enumerate(hue_categories):
#             hue_data = x_data[x_data[hue] == hue_val]
#             kwargs_no_color = {k: v for k, v in kwargs.items() if k != "color"}
#             plt.bar(i - width / 2 + j * width / len(hue_categories),
#                     hue_data[y].mean(),
#                     width=width / len(hue_categories),
#                     color=palette[hue_val],
#                     **kwargs_no_color)

# # Create FacetGrid with the custom barplot function
# g = sns.FacetGrid(data=MI_idx, col="condition", col_wrap=5, sharex=False, sharey=True, height=3, aspect=1)
# g.map_dataframe(custom_barplot, x="question", y="mean", hue="hue", width=5, palette=flattened_palette)

# # Create a legend outside the FacetGrid
# legend_elements = [Line2D([0], [0], color=color, lw=4, label=label) for label, color in flattened_palette.items()]
# plt.legend(handles=legend_elements, bbox_to_anchor=(1.05, 1.9), loc='upper left', title='Hue', title_fontsize=12)

# # Display the plot
# plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.lines import Line2D

def custom_barplot(x, y, hue, data, width, palette, **kwargs):
    x_categories = data[x].unique()
    hue_categories = data[hue].unique()
    
    for i, x_val in enumerate(x_categories):
        x_data = data[data[x] == x_val]
        for j, hue_val in enumerate(hue_categories):
            hue_data = x_data[x_data[hue] == hue_val]
            kwargs_no_color = {k: v for k, v in kwargs.items() if k != "color"}
            edge_color = "blue" if "liberal" in hue_val else "red"
            plt.bar(i - width / 2 + j * width / len(hue_categories),
                    hue_data[y].mean(),
                    width=width / len(hue_categories),
                    color=palette[hue_val],
                    edgecolor=edge_color,
                    linewidth=1.5,
                    **kwargs_no_color)

# Create FacetGrid with the custom barplot function
g = sns.FacetGrid(data=MI_idx, col="condition", col_wrap=5, sharex=False, sharey=True, height=3, aspect=1)
g.map_dataframe(custom_barplot, x="question", y="mean", hue="hue", width=13, palette=flattened_palette)

# Create a legend outside the FacetGrid
legend_elements = [Line2D([0], [0], color=color, lw=4, label=label) for label, color in flattened_palette.items()]
plt.legend(handles=legend_elements, bbox_to_anchor=(1.05, 1.9), loc='upper left', title='Hue', title_fontsize=12)

# Display the plot
plt.show()

# %%
x_categories = MI_idx["question"].unique()
[q[:3] for q in x_categories]
[i for i in range(len(x_categories))]
list(set(flattened_palette.keys()))
{color: f"My label {i}" for i, color in enumerate(unique_colors)}
flattened_palette
# Out:
# {'conservative_control': (0.65, 0.35, 0.0, 1.0),
#  'liberal_control': (0.65, 0.35, 0.0, 1.0),
#  'conservative_desired change': (0.0, 0.5, 0.0, 1.0),
#  'liberal_desired change': (0.0, 0.5, 0.0, 1.0),
#  'conservative_difficulty changing': (1.0, 0.498, 0.0, 1.0),
#  'liberal_difficulty changing': (1.0, 0.498, 0.0, 1.0),
#  'conservative_genes': (0.85, 0.325, 0.098, 1.0),
#  'liberal_genes': (0.85, 0.325, 0.098, 1.0),
#  'conservative_internal distress': (0.25, 0.88, 0.82, 1.0),
#  'liberal_internal distress': (0.25, 0.88, 0.82, 1.0),
#  'conservative_mental illness': (0.0, 0.447, 0.741, 1.0),
#  'liberal_mental illness': (0.0, 0.447, 0.741, 1.0),
#  'conservative_punishment': (0.5, 0.0, 0.5, 1.0),
#  'liberal_punishment': (0.5, 0.0, 0.5, 1.0),
#  'conservative_wrongness': (0.95, 0.6, 0.6, 1.0),
#  'liberal_wrongness': (0.95, 0.6, 0.6, 1.0)}

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.lines import Line2D

def custom_barplot(x, y, hue, data, width, palette, **kwargs):
    x_categories = data[x].unique()
    hue_categories = data[hue].unique()
    
    for i, x_val in enumerate(x_categories):
        x_data = data[data[x] == x_val]
        for j, hue_val in enumerate(hue_categories):
            hue_data = x_data[x_data[hue] == hue_val]
            kwargs_no_color = {k: v for k, v in kwargs.items() if k != "color"}
            edge_color = "blue" if "liberal" in hue_val else "red"
            plt.bar(i - width / 2 + j * width / len(hue_categories),
                    hue_data[y].mean(),
                    width=width / len(hue_categories),
                    color=palette[hue_val],
                    edgecolor=edge_color,
                    linewidth=1.5,
                    **kwargs_no_color)
    
    # Set x-axis limits for each facet
    g.set(xlim=(-8, 14))

    # Set x-tick labels to abbreviations of each question
    abbreviations = [q[:3] for q in x_categories]
    # tick_positions = [i for i in range(len(x_categories))]
    tick_positions = [-6, -3.5, -1, 1.8, 4.3, 7, 9.5, 12.3]
    plt.xticks(tick_positions, abbreviations, ha="center")

# Create FacetGrid with the custom barplot function
g = sns.FacetGrid(data=MI_idx, col="condition", col_wrap=5, sharex=False, sharey=True, height=3, aspect=1)
g.map_dataframe(custom_barplot, x="question", y="mean", hue="hue", width=13, palette=flattened_palette)

# Title
g.set_titles(fontweight='bold', col_template="{col_name}")

# flattened_palette is assumed to be a dictionary mapping label names to colors
unique_colors = list(set(flattened_palette.values()))

# Create a dictionary mapping colors to labels
# color_labels = {color: f"My label {i}" for i, color in enumerate(unique_colors)}

# Specify custom labels for each color
custom_labels = ["punishment", "genetics", "Label 3"] # replace with your custom labels

# Create legend elements for each unique color
# legend_elements = [Line2D([0], [0], color=color, lw=4, label=color_labels[color]) for color in unique_colors]
legend_elements = [Line2D([0], [0], color=unique_colors[i], lw=4, label=custom_labels[i]) for i in range(len(unique_colors))]

# Create a legend outside the FacetGrid
plt.legend(handles=legend_elements, bbox_to_anchor=(1.05, 1.9), loc='upper left', title='Hue', title_fontsize=12)

plt.show()

# %%
edge = {}

for y in set(MI_idx.politics):
    if y == "liberal":
        edge[y] = (0.0, 0.447, 0.741, 1.0)
    elif y == "conservative":
        edge[y] = (0.85, 0.325, 0.098, 1.0)

        
        
cols_list = list(cols.keys())

hue = {}

for i in np.arange(0, 14):
    if cols_list[i][1] = 
    hue[i] = cols_list[i][1]
hue

# %%
cols, hue, edge
# Out:
# ({'difficulty changing': (1.0, 0.498, 0.0, 1.0),
#   'control': (0.65, 0.35, 0.0, 1.0),
#   'genes': (0.85, 0.325, 0.098, 1.0),
#   'wrongness': (0.95, 0.6, 0.6, 1.0),
#   'punishment': (0.5, 0.0, 0.5, 1.0),
#   'mental illness': (0.0, 0.447, 0.741, 1.0),
#   'desired change': (0.0, 0.5, 0.0, 1.0)},
#  {'liberal': (0.0, 0.5, 0.0, 1.0), 'conservative': (0.0, 0.5, 0.0, 1.0)},
#  {'liberal': (0.0, 0.447, 0.741, 1.0),
#   'conservative': (0.85, 0.325, 0.098, 1.0)})
