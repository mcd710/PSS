# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.linalg import svd
from sklearn import linear_model
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
import scipy.stats as stats
import matplotlib.cm as cm
from IPython.display import display
from mpl_toolkits.mplot3d import Axes3D
from sklearn.feature_selection import f_regression
from statsmodels.stats.anova import anova_lm

from sklearn.preprocessing import PolynomialFeatures
import scipy.special

# %%
# MI_all = pd.read_csv('/Users/merieldoyle/Desktop/CK/condition.csv', index_col = False)
MI_all = pd.read_csv("/Users/merieldoyle/Desktop/ckMI/data/condition.csv", index_col = False)
MI_all = pd.DataFrame(MI_all)

# %% [markdown]
# ### Mental Illness * Control → Punishment

# %% [markdown]
# #### Across participants

# %%
MI_all['control_med'] = MI_all.control > MI_all.control.median()
MI_all['control_med'] = np.where(MI_all.control_med == False, 'below median', 'above median')

# %%
custom_titles = ['pedo', 'drugs', 'psycho', 'gay', 'fetish',
                 'racist', 'trans', 'obese', 'dep', 'schizo']

mc = sns.lmplot(
    data = MI_all, 
    x = 'mental', y = 'punish', 
    col = 'Condition', hue = 'control_med', col_wrap = 5,
    markers = 'o', legend = False,
    scatter_kws = {'alpha': 0.000001})
mc.set(ylim = (2.3, 6.3), xlim = (0.8, 7.2), ylabel = "", xlabel = "")

mc.add_legend(legend_data = mc._legend_data, 
              title = 'control_cat\n', # \n adds a space between title and elements
              prop = {'size': 16}, 
              edgecolor = 'lightgray',
              frameon = True, fancybox = True) # legend title
mc._legend.get_title().set_weight('bold') # bold title
mc._legend.get_title().set_size('17') # bold title

for lh in mc._legend.legendHandles: 
    lh.set_alpha(1)
    lh._sizes = [50] 
    
for ax, title in zip(mc.axes.flat, custom_titles):
    ax.set_title(title, fontsize = 16, fontweight = "bold")

mc.fig.suptitle('Mental Illness * Control → Punishment', x = 0.08, y = 0.93, size = 20, fontweight = "bold")
mc.fig.subplots_adjust(top = .83, hspace = 0.1)

mc.fig.text(0.47, -0.01, 'mental illness', ha='center', va='center', fontsize=16, fontweight='bold') # common x-label
mc.fig.text(-0.01, 0.45, 'punish', ha='center', va='center', fontsize=16, fontweight='bold', rotation='vertical') # common y-label

for ax in mc.axes.flat:
    ax.set_facecolor('#F0F0F0')  # set background color
    ax.yaxis.grid(True, linestyle='-', linewidth=1, alpha=1, color = 'white')  # faint horizontal gridlines
    ax.xaxis.grid(True, linestyle='-', linewidth=1, alpha=1, color = 'white')  # faint vertical gridlines
    ax.set_axisbelow(True)  # put gridlines below bar plots

plt.show(mc)

# %%
save_directory = "/Users/merieldoyle/Desktop/ckMI/results/figures/moderations"
file_name = "mental-control-punish.png"
save_path = save_directory + file_name

mc.savefig(save_path, dpi=300)

# %% [markdown]
# #### Across conditions
# ##### Do not run 6-15

# %%
# # calculate percentage of "above median" occurrences for each condition
# condition_perc = MI_all.groupby(['Condition', 'control_med']).size().unstack(fill_value=0).reset_index()
# condition_perc['above_median_perc'] = condition_perc['above median'] / (condition_perc['above median'] + condition_perc['below median']) * 100

# # sort by percentage of "above median" occurrences
# condition_perc_sorted = condition_perc.sort_values(by='above_median_perc', ascending=False)

# %%
# top_5 = condition_perc_sorted.head(5)
# bottom_5 = condition_perc_sorted.tail(5)

# selected_conditions = pd.concat([top_5, bottom_5])

# %%
# MI_filtered = MI_all[MI_all['Condition'].isin(selected_conditions['Condition'])]

# def set_control_hue(row):
#     if row['Condition'] in top_5['Condition'].values:
#         return 'above median'
#     else:
#         return 'below median'

# MI_filtered['control_hue'] = MI_filtered.apply(set_control_hue, axis=1)

# %%
# # GPT DID NOT TELL ME TO DO THIS

# MI_all = MI_filtered

# # calculate the mean 'control' value for each mental illness condition
# punish_mean_per_condition = MI_all.groupby('Condition')['punish'].mean().reset_index()

# # rename the columns to merge them later
# punish_mean_per_condition.columns = ['Condition', 'punish_mean']

# # merge the mean control values to the MI_all DataFrame, matching the rows based on the 'Condition' column
# MI_all = MI_all.merge(punish_mean_per_condition, on='Condition', how='left')

# # MI_all.control.median() = 3

# %%
# # GPT DID NOT TELL ME TO DO THIS

# # MI_all = MI_filtered

# mental_mean_per_condition = MI_all.groupby('Condition')['mental'].mean().reset_index()

# mental_mean_per_condition.columns = ['Condition', 'mental_mean']

# MI_all = MI_all.merge(mental_mean_per_condition, on='Condition', how='left')

# # MI_all.control.median() = 3

# MI_all

# %%
# MI_all.to_csv('/Users/merieldoyle/Desktop/ckMI/data/MI_all.csv', index=False)

# %%
MI_calc = pd.read_csv("/Users/merieldoyle/Desktop/ckMI/data/MI_calc.csv", index_col = False)
MI_calc
# Out:
#       Condition  mental  change  want_change  genes  punish  control  wrong  \
# 0          pedo     NaN     NaN          NaN    NaN     NaN      NaN    NaN
# 1          pedo     3.0     4.0          3.0    5.0     5.0      4.0    4.0
# 2          pedo     NaN     NaN          NaN    NaN     NaN      NaN    NaN
# 3          pedo     NaN     NaN          NaN    NaN     NaN      NaN    NaN
# 4          pedo     NaN     NaN          NaN    NaN     NaN      NaN    NaN
# ...         ...     ...     ...          ...    ...     ...      ...    ...
# 12225    schizo     NaN     NaN          NaN    NaN     NaN      NaN    NaN
# 12226    schizo     4.0     6.0          6.0    6.0     5.0      5.0    6.0
# 12227    schizo     7.0     7.0          5.0    4.0     4.0      1.0    1.0
# 12228    schizo     NaN     NaN          NaN    NaN     NaN      NaN    NaN
# 12229    schizo     NaN     NaN          NaN    NaN     NaN      NaN    NaN
#
#        distress  common   control_med   control_hue  punish_mean  mental_mean
# 0           NaN     NaN  below median  above median     5.408714     5.618257
# 1           4.0     8.0  above median  above median     5.408714     5.618257
# 2           NaN     NaN  below median  above median     5.408714     5.618257
# 3           NaN     NaN  below median  above median     5.408714     5.618257
# 4           NaN     NaN  below median  above median     5.408714     5.618257
# ...         ...     ...           ...           ...          ...          ...
# 12225       NaN     NaN  below median  below median     3.118503     6.363825
# 12226       4.0    77.0  above median  below median     3.118503     6.363825
# 12227       5.0    40.0  below median  below median     3.118503     6.363825
# 12228       NaN     NaN  below median  below median     3.118503     6.363825
# 12229       NaN     NaN  below median  below median     3.118503     6.363825
#
# [12230 rows x 14 columns]

# %%
# Create a scatterplot with hue
plt.figure(figsize=(10, 6))
mc = sns.scatterplot(
    data=MI_calc,
    x='mental_mean',
    y='punish_mean',
    hue='control_hue',
    alpha=0.005
)

# Get the unique hue categories
hue_categories = MI_calc['control_hue'].unique()

# For each hue category, plot a regression line with confidence intervals
for hue_category in hue_categories:
    data_subset = MI_calc[MI_calc['control_hue'] == hue_category]
    sns.regplot(
        data=data_subset,
        x='mental_mean',
        y='punish_mean',
        scatter=False,  # Hide the scatter points
        ci=95, # Show 95% confidence intervals
    )

plt.xlim(1.5, 7.2)
plt.ylim(1.5, 7.2)

plt.text(2, 6.5, 'Mental Illness * Control → Punitiveness', fontsize=11)

plt.show()

# %%
MI_all['control_med'] = MI_all.control > MI_all.control.median()
MI_all['control_med'] = np.where(MI_all.control_med == False, 'below median', 'above median')
MI_all
# Out:
#       Condition  mental  change  want_change  genes  punish  control  wrong  \
# 0          pedo     NaN     NaN          NaN    NaN     NaN      NaN    NaN
# 1          pedo     3.0     4.0          3.0    5.0     5.0      4.0    4.0
# 2          pedo     NaN     NaN          NaN    NaN     NaN      NaN    NaN
# 3          pedo     NaN     NaN          NaN    NaN     NaN      NaN    NaN
# 4          pedo     NaN     NaN          NaN    NaN     NaN      NaN    NaN
# ...         ...     ...     ...          ...    ...     ...      ...    ...
# 12225    schizo     NaN     NaN          NaN    NaN     NaN      NaN    NaN
# 12226    schizo     4.0     6.0          6.0    6.0     5.0      5.0    6.0
# 12227    schizo     7.0     7.0          5.0    4.0     4.0      1.0    1.0
# 12228    schizo     NaN     NaN          NaN    NaN     NaN      NaN    NaN
# 12229    schizo     NaN     NaN          NaN    NaN     NaN      NaN    NaN
#
#        distress  common   control_med
# 0           NaN     NaN  below median
# 1           4.0     8.0  above median
# 2           NaN     NaN  below median
# 3           NaN     NaN  below median
# 4           NaN     NaN  below median
# ...         ...     ...           ...
# 12225       NaN     NaN  below median
# 12226       4.0    77.0  above median
# 12227       5.0    40.0  below median
# 12228       NaN     NaN  below median
# 12229       NaN     NaN  below median
#
# [12230 rows x 11 columns]

# %%
# Calculate the number of "above median" occurrences for each condition
above_median_count = MI_all[MI_all['control_med'] == 'above median'].groupby('Condition')['control_med'].count()
above_median_count = above_median_count.sort_values(ascending=False)

# Identify the top 5 and bottom 5 conditions
top_5_conditions = above_median_count.head(5).index
bottom_5_conditions = above_median_count.tail(5).index

# Calculate mean values for 'mental', 'wrong', and 'punish' for each condition
mean_df = MI_all.groupby('Condition')[['mental', 'wrong', 'punish']].mean().reset_index()

# Add control_med column to mean_df based on the condition's ranking in occurrences of "above median"
mean_df['control_med'] = mean_df['Condition'].apply(lambda x: 'above median' if x in top_5_conditions else 'below median')

mean_df
# Out:
#   Condition    mental     wrong    punish   control_med
# 0       dep  4.563410  2.831601  3.821206  below median
# 1     drugs  3.674274  4.852697  4.454357  above median
# 2    fetish  3.250696  3.462396  4.130919  below median
# 3       gay  1.859213  2.356108  4.045549  below median
# 4     obese  2.165884  3.809077  4.018779  above median
# 5      pedo  5.618257  6.603734  5.408714  above median
# 6    psycho  5.877847  5.565217  4.784679  below median
# 7    racist  2.578189  6.236626  5.115226  above median
# 8    schizo  6.363825  3.343035  3.118503  below median
# 9     trans  2.951172  2.894531  4.078125  above median

# %%
# Define the colors for the two control_med categories
color_dict = {'below median': '#1f77b4', 'above median': '#ff7f0e'}

# Create a scatterplot with hue
plt.figure(figsize=(10, 6))
mc = sns.scatterplot(
    data=mean_df,
    x='mental',
    y='punish',
    hue='control_med',
    palette=color_dict,
    alpha=0.7,
)

# For each control_med category, plot a regression line with confidence intervals
for control_med_category in control_med_categories:
    data_subset = mean_df[mean_df['control_med'] == control_med_category]
    sns.regplot(
        data=data_subset,
        x='mental',
        y='punish',
        scatter=False,
        ci=95,
    )
    
# Add labels to each data point
for index, row in mean_df.iterrows():
    plt.text(
        row['mental'] + 0.05,
        row['punish'] + 0.05,
        row['Condition'],
        color=color_dict[row['control_med']],
        fontsize=10,
    )

plt.xlim(1.5, 7)
plt.ylim(1.5, 7)

plt.text(1.8, 6.5, 'Mental Illness * Control → Punitiveness', fontsize=11)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/q7/0p1jf63j7lx6ldgn2kdfqlz00000gn/T/ipykernel_45695/2195669825.py in <module>
#      14
#      15 # For each control_med category, plot a regression line with confidence intervals
# ---> 16 for control_med_category in control_med_categories:
#      17     data_subset = mean_df[mean_df['control_med'] == control_med_category]
#      18     sns.regplot(
#
# NameError: name 'control_med_categories' is not defined

# %%
# Create a scatterplot with hue
plt.figure(figsize=(10, 6))
mc = sns.scatterplot(
    data=mean_df,
    x='mental',
    y='punish',
    hue='control_med',
    palette=color_dict,
    alpha=0.7,
)

# For each control_med category, plot a regression line with confidence intervals
for control_med_category in control_med_categories:
    data_subset = mean_df[mean_df['control_med'] == control_med_category]
    sns.regplot(
        data=MI_all[MI_all['control_med'] == control_med_category],  # Use entire dataset for confidence intervals
# Out:
#   File "/var/folders/q7/0p1jf63j7lx6ldgn2kdfqlz00000gn/T/ipykernel_45695/3492934706.py", line 17
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# ### Mental Illness * Wrongness → Punishment

# %%
MI_all['wrong_med'] = MI_all.wrong > MI_all.wrong.median()
MI_all['wrong_med'] = np.where(MI_all.wrong_med == False, 'below median', 'above median')

# %%
custom_titles = ['pedo', 'drugs', 'psycho', 'gay', 'fetish',
                 'racist', 'trans', 'obese', 'dep', 'schizo']

mw = sns.lmplot(
    data = MI_all, 
    x = 'mental', y = 'punish', 
    col = 'Condition', hue = 'wrong_med', col_wrap = 5,
    markers = 'o', legend = False,
    scatter_kws = {'alpha': 0.000001})
mw.set(ylim = (2.3, 6.3), xlim = (0.8, 7.2), ylabel = "", xlabel = "")

mw.add_legend(legend_data = mw._legend_data, 
              title = 'wrong_cat\n', # \n adds a space between title and elements
              prop = {'size': 16}, 
              edgecolor = 'lightgray',
              frameon = True, fancybox = True) # legend title
mw._legend.get_title().set_weight('bold') # bold title
mw._legend.get_title().set_size('17') # bold title

for lh in mw._legend.legendHandles: 
    lh.set_alpha(1)
    lh._sizes = [50] 
    
for ax, title in zip(mw.axes.flat, custom_titles):
    ax.set_title(title, fontsize = 16, fontweight = "bold")

mw.fig.suptitle('Mental Illness * Wrongness → Punishment', x = 0.08, y = 0.93, size = 20, fontweight = "bold")
mw.fig.subplots_adjust(top = .83, hspace = 0.1)

mw.fig.text(0.47, -0.01, 'mental illness', ha='center', va='center', fontsize=16, fontweight='bold') # common x-label
mw.fig.text(-0.01, 0.45, 'punish', ha='center', va='center', fontsize=16, fontweight='bold', rotation='vertical') # common y-label

for ax in mw.axes.flat:
    ax.set_facecolor('#F0F0F0')  # set background color
    ax.yaxis.grid(True, linestyle='-', linewidth=1, alpha=1, color = 'white')  # faint horizontal gridlines
    ax.xaxis.grid(True, linestyle='-', linewidth=1, alpha=1, color = 'white')  # faint vertical gridlines
    ax.set_axisbelow(True)  # put gridlines below bar plots

plt.show(mw)

# %%
save_directory = "/Users/merieldoyle/Desktop/ckMI/figures/mediations/"
file_name = "mental-wrong-punish.png"
save_path = save_directory + file_name

mw.savefig(save_path, dpi=300)

# %%
# # calculate the mean 'control' value for each mental illness condition
# punish_mean_per_condition = MI_all.groupby('Condition')['punish'].mean().reset_index()

# # rename the columns to merge them later
# punish_mean_per_condition.columns = ['Condition', 'punish_mean']

# # Merge the mean control values to the MI_all DataFrame, matching the rows based on the 'Condition' column
# MI_all = MI_all.merge(punish_mean_per_condition, on='Condition', how='left')

# # MI_all.control.median() = 3

# MI_all

# %%
mc = sns.lmplot(
    data = MI_all, 
    x = 'mental', y = 'punish', hue = 'control_med', 
    markers = 'o', legend = False,
    scatter_kws = {'alpha': 0.000001})
mc.set(xlim = (0.8,7.2), ylim = (3.1, 5.3))

mc.add_legend(legend_data = mc._legend_data,
             title = 'MENTAL_CAT',)

for lh in mc._legend.legendHandles: 
    lh.set_alpha(1)
    lh._sizes = [50] 
    
plt.text(1, 5.1, 'Mental Illness *Control → Punitiveness', fontsize = 11)

plt.show(mc)
